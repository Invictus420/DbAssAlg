# %% [markdown]
# # DAT ASS: Algebraic Modeling

# %%
# %reload_ext sql

# %%
# %sql postgresql://appdev@data/appdev
# Out:
# 'Connected: appdev@appdev'

# %% [markdown]
# ## Question 1.

# %%
# %sql SELECT * FROM chinook.track WHERE genreid = 18 union SELECT * FROM chinook.track WHERE genreid = 20;
# Out:
# 39 rows affected.
# [(3248, 'Take the Celestra', 253, 3, 20, None, 2927677, 512381289, Decimal('1.99')),
#  (3243, 'Murder On the Rising Star', 253, 3, 20, None, 2935894, 551759986, Decimal('1.99')),
#  (3238, 'The Living Legend, Pt. 2', 253, 3, 20, None, 2923298, 515632754, Decimal('1.99')),
#  (3230, 'Lost Planet of the Gods, Pt. 2', 253, 3, 20, None, 2914664, 534343985, Decimal('1.99')),
#  (3249, 'The Hand of God', 253, 3, 20, None, 2924007, 536583079, Decimal('1.99')),
#  (3226, 'Battlestar Galactica, Pt. 1', 253, 3, 20, None, 2952702, 541359437, Decimal('1.99')),
#  (3242, 'The Man With Nine Lives', 253, 3, 20, None, 2956998, 577829804, Decimal('1.99')),
#  (2837, 'Crossroads, Pt. 1', 227, 3, 20, None, 2622622, 486233524, Decimal('1.99')),
#  (2827, 'Unfinished Business', 227, 3, 18, None, 2622038, 528499160, Decimal('1.99')),
#  (2836, 'The Son Also Rises', 227, 3, 18, None, 2621830, 499258498, Decimal('1.99')),
# ...

# %%
# %sql SELECT * FROM chinook.genre WHERE genreid = 18;
# Out:
# 1 rows affected.
# [(18, 'Science Fiction')]

# %%
# %sql SELECT * FROM chinook.genre WHERE genreid = 20;
# Out:
# 1 rows affected.
# [(20, 'Sci Fi & Fantasy')]

# %% [markdown]
# The results seems to be scifi related soundtracks.

# %% [markdown]
# ## Question 2.

# %%
# %sql SELECT * FROM chinook.invoice WHERE total > 5 intersect SELECT * FROM chinook.invoice WHERE total < 10;
# Out:
# 115 rows affected.
# [(396, 18, datetime.datetime(2013, 10, 8, 0, 0, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)), '627 Broadway', 'New York', 'NY', 'USA', '10012-2612', Decimal('8.91')),
#  (290, 32, datetime.datetime(2012, 6, 27, 0, 0, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)), '696 Osborne Street', 'Winnipeg', 'MB', 'Canada', 'R3L 2B9', Decimal('5.94')),
#  (185, 52, datetime.datetime(2011, 3, 20, 0, 0, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)), '202 Hoxton Street', 'London', None, 'United Kingdom', 'N1 5LH', Decimal('5.94')),
#  (53, 44, datetime.datetime(2009, 8, 11, 0, 0, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)), 'Porthaninkatu 9', 'Helsinki', None, 'Finland', '00530', Decimal('8.91')),
#  (10, 46, datetime.datetime(2009, 2, 3, 0, 0, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)), '3 Chatham Street', 'Dublin', 'Dublin', 'Ireland', None, Decimal('5.94')),
# ...

# %% [markdown]
# The resulting invoices have similarities in their total value, fx 8.91 and 5.94.

# %% [markdown]
# ## Question 3.

# %%
# %sql SELECT * FROM chinook.customer WHERE country = 'USA' except SELECT * FROM chinook.customer WHERE email LIKE '%yahoo.com';
# Out:
# 11 rows affected.
# [(21, 'Kathy', 'Chase', None, '801 W 4th Street', 'Reno', 'NV', 'USA', '89503', '+1 (775) 223-7665', None, 'kachase@hotmail.com', 5),
#  (22, 'Heather', 'Leacock', None, '120 S Orange Ave', 'Orlando', 'FL', 'USA', '32801', '+1 (407) 999-7788', None, 'hleacock@gmail.com', 4),
#  (16, 'Frank', 'Harris', 'Google Inc.', '1600 Amphitheatre Parkway', 'Mountain View', 'CA', 'USA', '94043-1351', '+1 (650) 253-0000', '+1 (650) 253-0000', 'fharris@google.com', 4),
#  (28, 'Julia', 'Barnett', None, '302 S 700 E', 'Salt Lake City', 'UT', 'USA', '84102', '+1 (801) 531-7272', None, 'jubarnett@gmail.com', 5),
#  (19, 'Tim', 'Goyer', 'Apple Inc.', '1 Infinite Loop', 'Cupertino', 'CA', 'USA', '95014', '+1 (408) 996-1010', '+1 (408) 996-1011', 'tgoyer@apple.com', 3),
#  (18, 'Michelle', 'Brooks', None, '627 Broadway', 'New York', 'NY', 'USA', '10012-2612', '+1 (212) 221-3546', '+1 (212) 221-4679', 'michelleb@aol.com', 3),
# ...

# %% [markdown]
# Surpisingly only 11 USA customers without a yahoo mail.

# %% [markdown]
# ## Question 4.

# %%
# %sql SELECT DISTINCT title FROM chinook.track, chinook.album WHERE composer LIKE '%Mozart%' union SELECT DISTINCT title FROM chinook.track, chinook.album WHERE composer LIKE '%Bach%'
# Out:
# 347 rows affected.
# [('The Ultimate Relexation Album',),
#  ('Bach: Goldberg Variations',),
#  ('Virtual XI',),
#  ('Instant Karma: The Amnesty International Campaign to Save Darfur',),
#  ('Judas 0: B-Sides and Rarities',),
#  ('Weill: The Seven Deadly Sins',),
#  ('Bongo Fury',),
#  ('Powerslave',),
#  ("Up An' Atom",),
#  ('Original Soundtracks 1',),
#  ('Arquivo II',),
#  ('Vs.',),
#  ('In Your Honor [Disc 2]',),
#  ('Come Taste The Band',),
#  ('King For A Day Fool For A Lifetime',),
#  ('St. Anger',),
#  ('Van Halen',),
#  ('BBC Sessions [Disc 1] [Live]',),
#  ('No More Tears (Remastered)',),
#  ('Revelations',),
#  ('My Generation - The Very Best Of The Who',),
#  ('Pure Cult: The Best Of The Cult (For Rockers, Ravers, Lovers & Sinners) [UK]',),
#  ('Stormbringer',),
#  ('The Real Thing',),
#  ('Aquaman',),
#  ('The Song Remains The Same (Disc 1)',),
#  ('Hot Rocks, 1964-1971 (Disc 1)',),
#  ('Jagged Little Pill',),
#  ('Outbreak',),
#  ('Serie Sem Limite (Disc 1)',),
# ...

# %%
# %sql SELECT DISTINCT * FROM chinook.track, chinook.album WHERE title = 'Judas 0: B-Sides and Rarities' AND (composer LIKE '%Bach' OR composer LIKE '%Mozart%')
# Out:
# 12 rows affected.
# [(3407, 'Concerto for 2 Violins in D Minor, BWV 1043: I. Vivace', 276, 2, 24, 'Johann Sebastian Bach', 193722, 3192890, Decimal('0.99'), 201, 'Judas 0: B-Sides and Rarities', 131),
#  (3408, 'Aria Mit 30 Veränderungen, BWV 988 "Goldberg Variations": Aria', 277, 2, 24, 'Johann Sebastian Bach', 120463, 2081895, Decimal('0.99'), 201, 'Judas 0: B-Sides and Rarities', 131),
#  (3409, 'Suite for Solo Cello No. 1 in G Major, BWV 1007: I. Prélude', 278, 2, 24, 'Johann Sebastian Bach', 143288, 2315495, Decimal('0.99'), 201, 'Judas 0: B-Sides and Rarities', 131),
#  (3412, '"Eine Kleine Nachtmusik" Serenade In G, K. 525: I. Allegro', 281, 2, 24, 'Wolfgang Amadeus Mozart', 348971, 5760129, Decimal('0.99'), 201, 'Judas 0: B-Sides and Rarities', 131),
#  (3413, 'Concerto for Clarinet in A Major, K. 622: II. Adagio', 282, 2, 24, 'Wolfgang Amadeus Mozart', 394482, 6474980, Decimal('0.99'), 201, 'Judas 0: B-Sides and Rarities', 131),
# ...

# %% [markdown]
# The results showed many albums, containing tracks that were composed by Mozart or Bach.
